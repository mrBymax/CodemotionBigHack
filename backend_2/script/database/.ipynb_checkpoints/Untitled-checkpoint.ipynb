# %%
import pandas as pd

# %%
data = pd.read_csv('Sheet0-Table1.csv', error_bad_lines=False, sep=';', header=0)

# %%
data
# Out:
#                     CATEGORY_NAME  LEVEL_NO       LEVEL_DESCR  RPN_CODE  \
# 0        Automotive Motor Control         2           Segment    261421
# 1     IoT for Smart Home and City         2           Segment    269707
# 2     IoT for Smart Home and City         2           Segment    271255
# 3          IoT for Smart Industry         2           Segment    271255
# 4            IoT for Smart Things         2           Segment    271255
# ...                           ...       ...               ...       ...
# 8850      eScooter micro-mobility         4  Cust-Application     64885
# 8851      eScooter micro-mobility         4  Cust-Application    263089
# 8852      eScooter micro-mobility         4  Cust-Application    133994
# 8853      eScooter micro-mobility         4  Cust-Application    264693
# 8854      eScooter micro-mobility         4  Cust-Application    267589
#
#           PART_NUMBER MARKETING_STATUS PUBLISHED  \
# 0          TwisterSIM           Active         Y
# ...

# %%
df = pd.DataFrame(data, columns=['CATEGORY_NAME', 'LEVEL_NO'])

# %%
df.set_index('LEVEL_NO')
# Out:
#                         CATEGORY_NAME
# LEVEL_NO
# 2            Automotive Motor Control
# 2         IoT for Smart Home and City
# 2         IoT for Smart Home and City
# 2              IoT for Smart Industry
# 2                IoT for Smart Things
# ...                               ...
# 4             eScooter micro-mobility
# 4             eScooter micro-mobility
# 4             eScooter micro-mobility
# 4             eScooter micro-mobility
# 4             eScooter micro-mobility
#
# [8855 rows x 1 columns]

# %%
category = input('insert the category')

# %%
df.loc[df['LEVEL_NO'] == 4 & df['CATEGORY_NAME'] == category]
# Out:
#                 CATEGORY_NAME  LEVEL_NO
# 214              24 GHz Radar         4
# 224              24 GHz Radar         4
# 234              24 GHz Radar         4
# 240    3-phase 6-STEP Control         4
# 241    3-phase 6-STEP Control         4
# ...                       ...       ...
# 8846  eScooter micro-mobility         4
# 8847  eScooter micro-mobility         4
# 8848  eScooter micro-mobility         4
# 8849  eScooter micro-mobility         4
# 8854  eScooter micro-mobility         4
#
# [3106 rows x 2 columns]
